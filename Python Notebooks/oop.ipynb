# %%
stuff = list()
print(dir(stuff))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
usf = input('Enter the US Floor Number: ')
wf = int(usf) - 1
print('Non-US Floor Number is',wf)
# Out:
# Non-US Floor Number is 32

# %%
#webscraping
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a') 
for tag in tags:
    print(tag.get('href', None))
# Out:
# https://www.w3schools.com
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# https://www.w3schools.com/videos/index.php
# /pro/index.php
# javascript:void(0)
# https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
# https://courses.w3schools.com/
# https://www.w3schools.com/spaces
# javascript:void(0);
# /default.asp
# /html/default.asp
# /css/default.asp
# /js/default.asp
# /sql/default.asp
# /python/default.asp
# /php/default.asp
# /bootstrap/bootstrap_ver.asp
# /howto/default.asp
# /w3css/default.asp
# /java/default.asp
# /jquery/default.asp
# /c/index.php
# /cpp/default.asp
# /cs/index.php
# /r/default.asp
# /react/default.asp
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# /html/default.asp
# /css/default.asp
# /css/css_rwd_intro.asp
# /bootstrap/bootstrap_ver.asp
# /w3css/default.asp
# /colors/default.asp
# /icons/default.asp
# /graphics/default.asp
# /graphics/svg_intro.asp
# /graphics/canvas_intro.asp
# ...

# %%
#first use of objects
class PartyAnimal: 
    x=0
    def party(self) :
        self.x = self.x + 1 
        print("So far",self.x)

an = PartyAnimal()
an.party()
an.party()
an.party()
PartyAnimal.party(an)
# Out:
# So far 1
# So far 2
# So far 3
# So far 4

# %%
class Dog:
  
    # class attribute
    attr1 = "mammal"
  
    # Instance attribute
    def __init__(self, name):
        self.name = name
          
    def speak(self):
        print("My name is {}".format(self.name))
  
# Driver code
# Object instantiation
Rodger = Dog("Rodger")
Tommy = Dog("Tommy")
  
# Accessing class methods
Rodger.speak()
Tommy.speak()
# Out:
# My name is Rodger
# My name is Tommy

# %%
import random
class BaliBoy:

    trip = "Bali"
    def __init__(self,name,board,style,trick):
        self.name = name
        self.board = board
        self.style = style
        self.trick = trick

k1 = BaliBoy("Ben","Twin Pin", "relaxed", "trop pop")
k2 = BaliBoy("Adam", "Fever", "noob", "pop up")
k3 = BaliBoy("Brayden", "Mayhem", "agressive", "breaks board")
k4 = BaliBoy("Rob","Safari Swallow","flowy","airs")
k5 = BaliBoy("Jake", "f22","confident","cut back")
k6 = BaliBoy("Sam","Twin Pin", "supreme kook","getting tubed")
k7 = BaliBoy("Chris", "Bilt", "durban style", "lip riding")

fout = open('bali.txt', 'w')
line1 = ("What to epxect of Kwedinis in Bali: ")
fout.write(line1)
line2=("\n"+"Name: " +k1.name + "\n" +" Board: " + k1.board + "\n"+  " Style: " + k1.style + "\n"+ " Trick: " + k1.trick + "\n" + "--------------")
fout.write(line2)
line3=("\n"+"Name: " +k2.name + "\n" +" Board: " + k2.board + "\n"+  " Style: " + k2.style + "\n"+ " Trick: " + k2.trick + "\n" + "--------------")
fout.write(line3)
line4=("\n"+"Name: " +k3.name + "\n" +" Board: " + k3.board + "\n"+  " Style: " + k3.style + "\n"+ " Trick: " + k3.trick + "\n" + "--------------")
fout.write(line4)
line5=("\n"+"Name: " +k4.name + "\n" +" Board: " + k4.board + "\n"+  " Style: " + k4.style + "\n"+ " Trick: " + k4.trick + "\n" + "--------------")
fout.write(line5)
line6=("\n"+"Name: " +k5.name + "\n" +" Board: " + k5.board + "\n"+  " Style: " + k5.style + "\n"+ " Trick: " + k5.trick + "\n" + "--------------")
fout.write(line6)
line7=("\n"+"Name: " +k6.name + "\n" +" Board: " + k6.board + "\n"+  " Style: " + k6.style + "\n"+ " Trick: " + k6.trick + "\n" + "--------------")
fout.write(line7)
line8=("\n"+"Name: " +k7.name + "\n" +" Board: " + k7.board + "\n"+  " Style: " + k7.style + "\n"+ " Trick: " + k7.trick + "\n" + "--------------")
fout.write(line8)

characters= [k1.name,k2.name,k3.name,k4.name,k5.name,k6.name,k7.name]
character = random.choice(characters)

line9 = "\n"+"Computers random guess of who will get the biggest tube: " + character
fout.write(line9)
# Out:
# 61

# %%
#object life cycle
class PartyAnimal: 
    x=0
    def __init__(self): 
        print('I am constructed')
    
    def party(self) :
        self.x = self.x + 1 
        print('So far',self.x)

    def __del__(self):
        print('I am destructed', self.x)

an = PartyAnimal()
an.party()
an.party()
an = 42
print('an contains',an)
# Out:
# I am constructed
# So far 1
# So far 2
# I am destructed 2
# an contains 42

# %%
#__init__ stands for initail value and gives us a chance to assign.

# %%
#inheritance

# parent class
class Person(object):
  
    # __init__ is known as the constructor
    def __init__(self, name, idnumber):
        self.name = name
        self.idnumber = idnumber
  
    def display(self):
        print(self.name)
        print(self.idnumber)
          
    def details(self):
        print("My name is {}".format(self.name))
        print("IdNumber: {}".format(self.idnumber))
      
# child class
class Employee(Person):
    def __init__(self, name, idnumber, salary, post):
        self.salary = salary
        self.post = post
  
        # invoking the __init__ of the parent class
        Person.__init__(self, name, idnumber)
          
    def details(self):
        print("My name is {}".format(self.name))
        print("IdNumber: {}".format(self.idnumber))
        print("Post: {}".format(self.post))
  
  
# creation of an object variable or an instance
a = Employee('Rahul', 886012, 200000, "Intern")

# calling a function of the class Person using
# its instance
a.display()
a.details()
# Out:
# Rahul
# 886012
# My name is Rahul
# IdNumber: 886012
# Post: Intern

# %%
#music example

class Song:
    
    def __innit__(self,artist,title,album, trackNo):
        self.artist = artist
        self.title = title
        self.album = album
        self.trackNo = trackNo

        self.add_song(self)

class Album:   
    
    def __innit__(self, artist, title, year):
        self.artist = artist
        self.title = title
        self.year = year

        self.tracks = []

        artist.add_album(self)


    def createPlaylist(self,artist,title,trackNo):
        
        trackNo = len(self.tracks)
        song = Song(self, artist, title, trackNo)
        self.tracks.append(song)

class Artist: 

    def __innit__(self, name):
        self.name = name 

        self.albums = []
        self.songs = []

    def addAlbum(self,album):
        self.albums.append(album)

    def addSong(self,song):
        self.songs.append(song)


class Playlist:

    def __innit__(self, name):
        self.name = name

        self.songs = []

    def addSong(self,song):
        self.songs.append(song)

# %%
band = Artist("Drake")
album = Album(band , "If you're reading this its too late",2014 )

album.add_track("6god")
album.add_track("legend")
album.add_track("energy")

playlist = Playlist("My fav songs")

for song in album.tracks:
    playlist.addSong(song)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/adamdanielgreen/Desktop/practiceA2/oop.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/adamdanielgreen/Desktop/practiceA2/oop.ipynb#ch0000012?line=0'>1</a> band = Artist("Drake")
#       <a href='vscode-notebook-cell:/Users/adamdanielgreen/Desktop/practiceA2/oop.ipynb#ch0000012?line=1'>2</a> album = Album(band , "If you're reading this its too late",2014 )
#       <a href='vscode-notebook-cell:/Users/adamdanielgreen/Desktop/practiceA2/oop.ipynb#ch0000012?line=2'>3</a> album.add_track("6god")
#
# TypeError: Artist() takes no arguments

# %%
for song in playlist.songs:
    print(song.title + "by" + str(song.artist.name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/adamdanielgreen/Desktop/practiceA2/oop.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/adamdanielgreen/Desktop/practiceA2/oop.ipynb#ch0000013?line=0'>1</a> for song in playlist.songs:
#       <a href='vscode-notebook-cell:/Users/adamdanielgreen/Desktop/practiceA2/oop.ipynb#ch0000013?line=1'>2</a>     print(song.title + "by" + str(song.artist.name))
#
# NameError: name 'playlist' is not defined

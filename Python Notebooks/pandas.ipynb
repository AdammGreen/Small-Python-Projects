# %%
import pandas as pd

actor = ["adam", "dong", "long", "dingdong"]

actor_series = pd.Series(actor)
#print(actor_series)

heading_for_frame = {"actor": actor_series}

author_df = pd.DataFrame(heading_for_frame)

author_df
# Out:
#       actor
# 0      adam
# 1      dong
# 2      long
# 3  dingdong

# %%
#use this way not first cell way
import pandas as pd

lst = [["David", "Green",60],["Jed", "Green",19],["Mailie","Green",57], ["Adam", "Green",21]]

df = pd.DataFrame(lst,columns = ["Fname","lName","Age"], dtype=float)

df
# Out:
# /var/folders/vn/cc7txpfd13n_6z08g5s2xs_80000gn/T/ipykernel_21310/355555185.py:5: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df = pd.DataFrame(lst,columns = ["Fname","lName","Age"], dtype=float)
#     Fname  lName   Age
# 0   David  Green  60.0
# 1     Jed  Green  19.0
# 2  Mailie  Green  57.0
# 3    Adam  Green  21.0

# %%
import pandas as pd

movies_df = pd.read_csv("/Users/adamdanielgreen/Desktop/practiceA2/IMDB-Movie-Data .csv",index_col="Title")

# %%
movies_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
movies_df['Genre'].value_counts().head(20)
# Out:
# Action,Adventure,Sci-Fi       50
# Drama                         48
# Comedy,Drama,Romance          35
# Comedy                        32
# Drama,Romance                 31
# Animation,Adventure,Comedy    27
# Action,Adventure,Fantasy      27
# Comedy,Drama                  27
# Comedy,Romance                26
# Crime,Drama,Thriller          24
# Crime,Drama,Mystery           23
# Action,Adventure,Drama        18
# Action,Crime,Drama            17
# Horror,Thriller               16
# Drama,Thriller                15
# Adventure,Family,Fantasy      14
# Biography,Drama,History       14
# Action,Adventure,Comedy       14
# Biography,Drama               14
# Action,Comedy,Crime           12
# Name: Genre, dtype: int64

# %%
import pandas as pd

movies_df = pd.read_csv("/Users/adamdanielgreen/Desktop/practiceA2/IMDB-Movie-Data .csv",index_col="Title")

movies_df.rename(columns={"Runtime (Minutes)":'Runtime', "Revenue (Millions)":'Revenue_millions'},inplace=True)

movies_df['Revenue_millions'].max()
# Out:
# 936.63

# %%
import pandas as pd

movies_df = pd.read_csv("/Users/adamdanielgreen/Desktop/practiceA2/IMDB-Movie-Data .csv")

movies_df.rename(columns={"Runtime (Minutes)":'Runtime', "Revenue (Millions)":'Revenue_millions'},inplace=True)

directors_df = movies_df.groupby("Director")
revenue_df = directors_df[["Title","Revenue_millions"]].mean()

revenue_df.head(25)
# Out:
#                              Revenue_millions
# Director
# Aamir Khan                           1.200000
# Abdellatif Kechiche                  2.200000
# Adam Leon                                 NaN
# Adam McKay                         109.535000
# Adam Shankman                       78.665000
# Adam Wingard                        10.535000
# Afonso Poyart                             NaN
# Aisling Walsh                             NaN
# Akan Satayev                              NaN
# Akiva Schaffer                       9.390000
# Alan Taylor                        148.045000
# Albert Hughes                       94.820000
# Alejandro Amenábar                   0.050000
# Alejandro González Iñárritu         86.760000
# Alessandro Carloni                 143.520000
# Alex Garland                        25.440000
# Alex Proyas                         31.140000
# Alex Ranarivelo                           NaN
# Alexander Payne                     82.620000
# ...

# %%
import pandas as pd

movies_df = pd.read_csv("/Users/adamdanielgreen/Desktop/practiceA2/IMDB-Movie-Data .csv",index_col="Title")

movies_df.rename(columns={"Runtime (Minutes)":'Runtime', "Revenue (Millions)":'Revenue_millions'},inplace=True)

subset = movies_df[['Rank','Rating']]

subset.corr()
# Out:
#             Rank    Rating
# Rank    1.000000 -0.219555
# Rating -0.219555  1.000000

# %%
import pandas as pd

movies_df = pd.read_csv("/Users/adamdanielgreen/Desktop/practiceA2/IMDB-Movie-Data .csv",index_col="Title")

movies_df.rename(columns={"Runtime (Minutes)":'Runtime', "Revenue (Millions)":'Revenue_millions'},inplace=True)

subset = movies_df[['Rank','Rating','Revenue_millions','Runtime']]

subset.corr()
# Out:
#                       Rank    Rating  Revenue_millions   Runtime
# Rank              1.000000 -0.219555         -0.271592 -0.221739
# Rating           -0.219555  1.000000          0.217654  0.392214
# Revenue_millions -0.271592  0.217654          1.000000  0.267953
# Runtime          -0.221739  0.392214          0.267953  1.000000
